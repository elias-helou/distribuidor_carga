# %%
import os
import json

# %%
# Pasta onde estão os JSONs
pasta = 'formularios'
resultado = {"versao": "3.0", "formularios": {}, "disciplinas": {}, "docentes": [], "saldos": {}}

# %% [markdown]
# # Formulários

# %%
nomesArquivos = []

# %%
# Percorre todos os arquivos .json da pasta
for arquivo in os.listdir(pasta):
    if arquivo.endswith('.json'):
        caminho = os.path.join(pasta, arquivo)
        nomesArquivos.append(arquivo.split('.')[0])
        with open(caminho, 'r', encoding='utf-8') as f:
            dados = json.load(f)
            for nome, info in dados.items():
                resultado["formularios"][arquivo.split('.')[0]] = info.get("formularios", {})
                # resultado["docentes"].append({"nome": nome, "ativo": True})

# %%
resultado['formularios']
# Out:
# {'Adriano Kamimura Suzuki': {'SME0800,1': 1,
#   'EST5106,1': 2,
#   'EST5804,1': 3,
#   'SME0320,3': 4,
#   'SME0320,2': 5,
#   'SME0809,1': 6,
#   'SME0810,1': 7,
#   'SME0220,1': 10,
#   'SME0320,4': 8,
#   'SME0320,1': 9},
#  'Afonso Paiva Neto': {'SME0241,1': 1,
#   'SME0300,1': 2,
#   'SME0300,2': 3,
#   'SME0306,1': 4,
#   'SME0306,2': 6,
#   'SME0250,1': 9,
#   'SME0334,1': 7,
#   'SME0206,1': 5,
#   'SME5827,1': 10,
#   'MAI5014,1': 8},
#  'Antonio Castelo Filho': {'SME0250,1': 1,
#   'SME5827,1': 2,
#   'MAI5002,1': 3,
#   'SME0206,1': 4,
#   'SME0334,1': 5,
#   'SME0300,2': 6,
#   'SME0300,1': 7,
#   'SME0306,1': 8,
#   'SME0306,2': 9,
#   'SME0241,1': 10},
#  'Cibele Maria Russo Novelli': {'SME0822,1': 1,
#   'SME0123,1': 2,
#   'SME0123,2': 3,
#   'SME0320,4': 4,
#   'SME0820,1': 5,
#   'SME0828,1': 6,
#   'SME0880,1': 7,
#   'SME5975,1': 9,
#   'EST5507,1': 8,
#   'EST5519,1': 10},
#  'Cynthia de Oliveira Lage Ferreira': {'SME0142,1': 1,
#   'SME0142,2': 2,
#   'SME0300,1': 4,
#   'SME0300,2': 8,
#   'SME0306,2': 5,
#   'SME0341,2': 3,
#   'SME0206,1': 6,
#   'SME0240,1': 9,
#   'SME0341,1': 7,
#   'SME0285,1': 10},
#  'Daiane de Souza Santos': {'SME0123,1': 1,
#   'SME0220,1': 5,
#   'SME0320,4': 2,
#   'SME0820,1': 9,
#   'SME0320,3': 3,
#   'SME0320,1': 4,
#   'SME0320,2': 6,
#   'SME0123,2': 7,
#   'SME0800,1': 10,
#   'SME0824,1': 8},
#  'Daniel Henrique Silva': {'SME0300,2': 1,
#   'SME0300,1': 2,
#   'SME0341,1': 3,
#   'SME0341,2': 4,
#   'SME0510,1': 5,
#   'SME0142,1': 6,
#   'SME0142,2': 7,
#   'SME0110,2': 8,
#   'SME0110,1': 9,
#   'SME0211,1': 10},
#  'Eduardo Fontoura Costa': {'SME0300,2': 2,
#   'SME0300,1': 1,
#   'SME0123,1': 3,
#   'SME0123,2': 4,
#   'SME0320,4': 5,
#   'SME0320,3': 6,
#   'SME0805,1': 8,
#   'SME0306,1': 9,
#   'SME0306,2': 10,
#   'SME0334,1': 7},
#  'Elias Salomão Helou Neto': {'SME0211,1': 4,
#   'SME0212,1': 3,
#   'SME0284,1': 1,
#   'SME0285,1': 2,
#   'SME0510,1': 5,
#   'SME0332,1': 6,
#   'SME0332,2': 7,
#   'SME0300,2': 8,
#   'SME0300,1': 9,
#   'SME0306,1': 10,
#   'SME0306,2': 11},
#  'Fabrício Simeoni de Sousa': {'MAI5014,1': 1,
#   'SME0252,1': 2,
#   'SME5873,1': 3,
#   'SME0206,1': 4,
#   'SME0300,1': 5,
#   'SME0241,1': 6,
#   'SME0250,1': 7,
#   'SME5827,1': 8,
#   'SME0820,1': 9,
#   'SME0300,2': 10},
#  'Francisco Aparecido Rodrigues': {'MAI5003,1': 10,
#   'SME0130,1': 1,
#   'SME0220,1': 6,
#   'SME0241,1': 7,
#   'SME0320,2': 3,
#   'SME0320,3': 5,
#   'SME0800,1': 9,
#   'SME0828,1': 4,
#   'SME5975,1': 2,
#   'SME5978,1': 8},
#  'Francisco Louzada Neto': {'MAI5003,1': 1,
#   'EST5804,1': 2,
#   'MAI5014,1': 3,
#   'SME0815,1': 4,
#   'EST5519,1': 5,
#   'EST5521,1': 6,
#   'SME0880,1': 7,
#   'SME0881,1': 8,
#   'EST5106,1': 9,
#   'SME0809,1': 10},
#  'Franklina Maria Bragion de Toledo': {'SME0110,1': 3,
#   'SME0110,2': 4,
#   'SME0211,1': 7,
#   'SME0212,1': 9,
#   'SME0213,1': 1,
#   'SME0300,1': 8,
#   'SME0510,1': 5,
#   'SME5962,1': 2,
#   'SME0285,1': 6,
#   'MAI5032,1': 10},
#  'Geovane Augusto Haveroth': {'SME0300,2': 10,
#   'SME0306,2': 9,
#   'SME0334,1': 8,
#   'SME0306,1': 7,
#   'SME0142,2': 6,
#   'SME0206,1': 4,
#   'SME0285,1': 2,
#   'SME0300,1': 5,
#   'SME0142,1': 3,
#   'SME0245,1': 1},
#  'Gustavo Carlos Buscaglia': {'MAI5002,1': 10,
#   'SME0123,1': 9,
#   'SME0123,2': 8,
#   'SME0206,1': 3,
#   'SME0241,1': 11,
#   'SME0300,1': 7,
#   'SME0300,2': 6,
#   'SME0306,2': 5,
#   'SME0306,1': 4,
#   'SME0285,1': 2,
#   'SME0284,1': 1},
#  'Katiane Silva Conceição': {'EST5106,1': 2,
#   'SME0123,1': 5,
#   'SME0123,2': 6,
#   'SME0810,1': 1,
#   'SME0320,4': 3,
#   'SME0320,2': 4,
#   'SME0814,1': 7,
#   'SME0815,1': 8,
#   'SME0880,1': 9,
#   'SME0881,1': 10},
#  'Leandro Franco de Souza': {'SME0306,1': 1,
#   'SME0300,1': 2,
#   'SME0306,2': 3,
#   'SME5873,1': 4,
#   'SME0300,2': 5,
#   'SME0252,1': 6,
#   'SME0334,1': 7,
#   'SME0284,1': 8,
#   'SME0285,1': 9,
#   'SME0814,1': 10},
#  'Livia Souza Freire Grion': {'SME0334,1': 1,
#   'SME0300,1': 2,
#   'SME0300,2': 3,
#   'SME0306,1': 4,
#   'SME0306,2': 5,
#   'SME0824,1': 10,
#   'SME0320,1': 8,
#   'SME0320,3': 9,
#   'SME0332,1': 6,
#   'SME0332,2': 7},
#  'Luis Gustavo Nonato': {'SME0142,1': 1,
#   'SME0241,1': 2,
#   'SME0123,2': 4,
#   'SME0300,2': 8,
#   'SME0306,1': 7,
#   'SME0320,2': 9,
#   'SME0334,1': 10,
#   'SME5975,1': 5,
#   'SME0142,2': 3,
#   'MAI5014,1': 6,
#   'SME0808,1': 11},
#  'Marcos Mansano Furlan': {'SME0110,1': 1,
#   'SME0110,2': 2,
#   'SME0211,1': 3,
#   'SME0510,1': 4,
#   'SME0332,1': 5,
#   'SME0332,2': 6,
#   'SME0300,2': 7,
#   'SME0300,1': 8,
#   'SME0212,1': 9,
#   'SME0828,1': 10},
#  'Maria Luísa Bambozzi de Oliveira': {'SME0142,1': 6,
#   'SME0142,2': 5,
#   'SME0206,1': 1,
#   'SME0240,1': 4,
#   'SME0300,1': 2,
#   'SME0300,2': 3,
#   'SME0306,2': 9,
#   'SME0341,1': 8,
#   'SME0341,2': 7,
#   'SME0241,1': 15},
#  'Mariana Cúri': {'SME0814,1': 1,
#   'SME0871,1': 2,
#   'SME0880,1': 4,
#   'SME0815,1': 3,
#   'SME0881,1': 5,
#   'SME5975,1': 6,
#   'SME0123,2': 7,
#   'EST5102,1': 8,
#   'SME0123,1': 9,
#   'SME0870,1': 10},
#  'Marina Andretta': {'SME0110,1': 4,
#   'SME0110,2': 3,
#   'SME0213,1': 6,
#   'SME0212,1': 1,
#   'SME0211,1': 2,
#   'SME0284,1': 10,
#   'SME0285,1': 9,
#   'SME0332,1': 7,
#   'SME0332,2': 8,
#   'SME0510,1': 5},
#  'Marinho Gomes de Andrade Filho': {'SME0220,1': 2,
#   'SME0320,2': 6,
#   'SME0320,3': 4,
#   'SME0320,4': 5,
#   'SME0805,1': 3,
#   'SME0808,1': 1,
#   'SME0262,1': 7,
#   'SME0809,1': 8,
#   'SME0823,1': 9,
#   'SME0870,1': 10},
#  'Maristela Oliveira dos Santos': {'SME0110,1': 1,
#   'SME0110,2': 2,
#   'SME0211,1': 3,
#   'MAI5032,1': 4,
#   'SME0510,1': 5,
#   'SME0213,1': 6,
#   'SME0284,1': 7,
#   'SME0285,1': 8,
#   'SME5962,1': 9,
#   'MAI5014,1': 10},
#  'Mário de Castro Andrade Filho': {'EST5102,1': 2,
#   'EST5507,1': 3,
#   'SME0220,1': 4,
#   'SME0800,1': 6,
#   'SME0871,1': 7,
#   'SME0820,1': 1,
#   'SME0822,1': 5,
#   'EST5802,1': 8,
#   'SME0320,3': 9,
#   'SME0320,4': 10},
#  'Paulo Afonso Faria da Veiga': {'SME0240,1': 1,
#   'SME0341,1': 2,
#   'SME0341,2': 3,
#   'SME0245,1': 4,
#   'SME0142,2': 6,
#   'SME0142,1': 5,
#   'SME0220,1': 9,
#   'SME0800,1': 10,
#   'SME0285,1': 7,
#   'SME0206,1': 8},
#  'Reiko Aoki': {'SME0123,1': 1,
#   'SME0123,2': 3,
#   'SME0320,1': 5,
#   'SME0320,2': 4,
#   'SME0320,3': 7,
#   'SME0320,4': 6,
#   'SME0820,1': 2,
#   'SME0220,1': 8,
#   'SME0814,1': 9,
#   'SME0800,1': 10},
#  'Ricardo Sandes Ehlers': {'SME0320,3': 1,
#   'SME0320,4': 6,
#   'SME0806,1': 5,
#   'SME0808,1': 7,
#   'SME0809,1': 8,
#   'SME0822,1': 9,
#   'EST5106,1': 3,
#   'EST5514,1': 2,
#   'SME0123,1': 4,
#   'SME0220,1': 10},
#  'Roberto Federico Ausas': {'SME0332,1': 1,
#   'SME0332,2': 2,
#   'SME0306,1': 3,
#   'SME0300,1': 4,
#   'SME0306,2': 5,
#   'SME0300,2': 6,
#   'SME5873,1': 7,
#   'SME0252,1': 8,
#   'SME0241,1': 10,
#   'SME0334,1': 9,
#   'SME0284,1': 11,
#   'SME0206,1': 12,
#   'SME0828,1': 13},
#  "Thomas Kauê Dal'Maso Peron": {'SME0123,2': 1,
#   'SME0123,1': 2,
#   'SME0320,3': 3,
#   'SME0320,1': 4,
#   'SME0820,1': 5,
#   'SME0320,2': 6,
#   'SME0320,4': 7,
#   'SME0130,1': 8,
#   'SME0828,1': 9,
#   'SME5978,1': 10},
#  'Tiago Pereira da Silva': {'SMA5802,1': 1,
#   'SMA5934,1': 2,
#   'PRG0027,1': 3,
#   'SME0130,1': 5,
#   'SME0142,2': 6,
#   'SME0142,1': 7,
#   'SME0240,1': 8,
#   'SME0245,1': 4,
#   'SME0241,1': 9,
#   'SME0320,1': 10}}

# %% [markdown]
# # Disciplinas

# %%
disciplinas: list[dict] = json.load(open('turmas.json', 'r',  encoding='utf-8'))

# %%
for d in disciplinas:
    d['cursos'] = d['curso']
    d['docentes'] = [] # Aproveitando que já está sendo iterado
    del d['curso']

# %% [markdown]
# ## Ajustar as turmas adicionando o campo "docentes"

# %%
dictPlinas = {disciplinas[i]['id'] : disciplinas[i] for i in range(len(disciplinas))}

# %%
for docente, turmasDocente in resultado.get("formularios", {}).items():
    if not turmasDocente:
        continue

    for turma in turmasDocente.keys():
        tDict = dictPlinas.get(turma)
        if tDict is not None:
            tDict.setdefault('docentes', []).append(docente)

# %%
resultado["disciplinas"] = disciplinas

# %% [markdown]
# # Docentes e Saldos

# %%
import pandas as pd

# %%
df = pd.read_excel("_ICMC _listagem docentes-somente docentes SME.xls")

# %%
df.drop(columns=["E-mail", 'Nº USP'])
# Out:
#                                                Nome  saldo
# 0                           Adriano Kamimura Suzuki      1
# 1                                 Afonso Paiva Neto      1
# 2   André Carlos Ponce de Leon Ferreira de Carvalho      1
# 3                             Antonio Castelo Filho      1
# 4                        Cibele Maria Russo Novelli      1
# 5                 Cynthia de Oliveira Lage Ferreira      1
# 6                            Daiane de Souza Santos      1
# 7                             Daniel Henrique Silva      1
# 8                            Eduardo Fontoura Costa      1
# 9                          Elias Salomão Helou Neto      1
# 10                        Everaldo de Mello Bonotto      1
# 11                        Fabrício Simeoni de Sousa      1
# 12                    Francisco Aparecido Rodrigues      1
# 13                           Francisco Louzada Neto      1
# 14                Franklina Maria Bragion de Toledo      1
# 15                         Geovane Augusto Haveroth      1
# 16                         Gustavo Carlos Buscaglia      1
# 17                          Jorge Luis Bazán Guzmán      1
# 18                            José Alberto Cuminato      1
# 19                          Katiane Silva Conceição      1
# 20                          Leandro Franco de Souza      1
# 21                         Livia Souza Freire Grion      1
# 22                              Luis Gustavo Nonato      1
# 23                            Marcos Mansano Furlan      1
# 24                 Maria Luísa Bambozzi de Oliveira      1
# 25                                     Mariana Cúri      1
# 26                                  Marina Andretta      1
# 27                   Marinho Gomes de Andrade Filho      1
# 28                    Mário de Castro Andrade Filho      1
# 29                    Maristela Oliveira dos Santos      1
# 30                  Miguel Vinicius Santini Frasson      1
# 31                   Oilson Alberto Gonzatto Junior      1
# 32                      Paulo Afonso Faria da Veiga      1
# 33                                       Reiko Aoki      1
# 34                            Ricardo Sandes Ehlers      1
# 35                           Roberto Federico Ausas      1
# 36                       Thomas Kauê Dal'Maso Peron      1
# 37                           Tiago Pereira da Silva      1
# 38                           Vicente Garibay Cancho      1

# %%
for nome, saldo in zip(df['Nome'], df['saldo']):
    resultado["docentes"].append({'nome': nome, "ativo": True})
    resultado["saldos"].update({nome: saldo})

# %%
resultado["saldos"].keys()
# Out:
# dict_keys(['Adriano Kamimura Suzuki', 'Afonso Paiva Neto', 'André Carlos Ponce de Leon Ferreira de Carvalho', 'Antonio Castelo Filho', 'Cibele Maria Russo Novelli', 'Cynthia de Oliveira Lage Ferreira', 'Daiane de Souza Santos', 'Daniel Henrique Silva', 'Eduardo Fontoura Costa', 'Elias Salomão Helou Neto', 'Everaldo de Mello Bonotto', 'Fabrício Simeoni de Sousa', 'Francisco Aparecido Rodrigues', 'Francisco Louzada Neto', 'Franklina Maria Bragion de Toledo', 'Geovane Augusto Haveroth', 'Gustavo Carlos Buscaglia', 'Jorge Luis Bazán Guzmán', 'José Alberto Cuminato', 'Katiane Silva Conceição', 'Leandro Franco de Souza', 'Livia Souza Freire Grion', 'Luis Gustavo Nonato', 'Marcos Mansano Furlan', 'Maria Luísa Bambozzi de Oliveira', 'Mariana Cúri', 'Marina Andretta', 'Marinho Gomes de Andrade Filho', 'Mário de Castro Andrade Filho', 'Maristela Oliveira dos Santos', 'Miguel Vinicius Santini Frasson', 'Oilson Alberto Gonzatto Junior', 'Paulo Afonso Faria da Veiga', 'Reiko Aoki', 'Ricardo Sandes Ehlers', 'Roberto Federico Ausas', "Thomas Kauê Dal'Maso Peron", 'Tiago Pereira da Silva', 'Vicente Garibay Cancho'])

# %%
nomesArquivos
# Out:
# ['Adriano Kamimura Suzuki',
#  'Afonso Paiva Neto',
#  'Antonio Castelo Filho',
#  'Cibele Maria Russo Novelli',
#  'Cynthia de Oliveira Lage Ferreira',
#  'Daiane de Souza Santos',
#  'Daniel Henrique Silva',
#  'Eduardo Fontoura Costa',
#  'Elias Salomão Helou Neto',
#  'Fabrício Simeoni de Sousa',
#  'Francisco Aparecido Rodrigues',
#  'Francisco Louzada Neto',
#  'Franklina Maria Bragion de Toledo',
#  'Geovane Augusto Haveroth',
#  'Gustavo Carlos Buscaglia',
#  'Katiane Silva Conceição',
#  'Leandro Franco de Souza',
#  'Livia Souza Freire Grion',
#  'Luis Gustavo Nonato',
#  'Marcos Mansano Furlan',
#  'Maria Luísa Bambozzi de Oliveira',
#  'Mariana Cúri',
#  'Marina Andretta',
#  'Marinho Gomes de Andrade Filho',
#  'Maristela Oliveira dos Santos',
#  'Mário de Castro Andrade Filho',
#  'Paulo Afonso Faria da Veiga',
#  'Reiko Aoki',
#  'Ricardo Sandes Ehlers',
#  'Roberto Federico Ausas',
#  "Thomas Kauê Dal'Maso Peron",
#  'Tiago Pereira da Silva']

# %%
print('Arquivos com nomes erradas:')
for nome in nomesArquivos:
    if nome not in resultado["saldos"].keys():
        print(nome)

# %%
print('Docentes que não entregaram os formulários:')
for nome in resultado['saldos'].keys():
    if nome not in nomesArquivos:
        print(nome)
# Out:
# Docentes que não entregaram os formulários:
# André Carlos Ponce de Leon Ferreira de Carvalho
# Everaldo de Mello Bonotto
# Jorge Luis Bazán Guzmán
# José Alberto Cuminato
# Miguel Vinicius Santini Frasson
# Oilson Alberto Gonzatto Junior
# Vicente Garibay Cancho

# %%
# Se quiser salvar esse resultado em um novo arquivo:
with open('formularios_combinados.json', 'w', encoding='utf-8') as f:
    json.dump(resultado, f, ensure_ascii=False, indent=2)
